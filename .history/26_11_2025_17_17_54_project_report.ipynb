# %%
#libraries
library(tidyverse)
library(repr)
library(tidymodels)
options(repr.matrix.max.rows = 6)
# source("cleanup.R")
library(lubridate)

# %%
# importing the data
players_data <- read_csv("https://raw.githubusercontent.com/CSof-student/DSCI100_GROUP_25_PROJECT/refs/heads/main/data/players.csv")
sessions_data <- read_csv("https://raw.githubusercontent.com/CSof-student/DSCI100_GROUP_25_PROJECT/refs/heads/main/data/sessions.csv")
players_data
sessions_data

# %%
what <- sessions_data |>
    mutate(original_start_time = as.Date(original_start_time)) |>
    mutate(original_end_time = as.Date(original_end_time))
    mutate(uhh = difftime(start_time, end_time))

what
